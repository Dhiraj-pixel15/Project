# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
Auto=pd.read_csv("HMC.csv")

# %%
Auto
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2020-01-02  28.600000  28.650000  28.459999  28.639999  26.480253
# 1     2020-01-03  28.250000  28.379999  28.080000  28.129999  26.008713
# 2     2020-01-06  27.719999  28.059999  27.719999  28.049999  25.934746
# 3     2020-01-07  28.389999  28.389999  28.180000  28.209999  26.082678
# 4     2020-01-08  27.990000  28.219999  27.990000  28.129999  26.008713
# ...          ...        ...        ...        ...        ...        ...
# 1084  2024-04-24  34.700001  34.700001  34.330002  34.410000  34.410000
# 1085  2024-04-25  33.549999  33.730000  33.310001  33.650002  33.650002
# 1086  2024-04-26  33.639999  33.900002  33.630001  33.849998  33.849998
# 1087  2024-04-29  33.990002  34.110001  33.950001  34.099998  34.099998
# 1088  2024-04-30  34.279999  34.389999  33.990002  33.990002  33.990002
#
#        Volume
# 0      262800
# 1      663600
# 2      463000
# 3      341800
# 4      264200
# ...

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1089 entries, 0 to 1088
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1089 non-null   object
#  1   Open       1089 non-null   float64
#  2   High       1089 non-null   float64
#  3   Low        1089 non-null   float64
#  4   Close      1089 non-null   float64
#  5   Adj Close  1089 non-null   float64
#  6   Volume     1089 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 59.7+ KB

# %%
for col in Auto:
    print(col,":",Auto[col].unique())
    print("*************************************************")
# Out:
# Date : ['2020-01-02' '2020-01-03' '2020-01-06' ... '2024-04-26' '2024-04-29'
#  '2024-04-30']
# *************************************************
# Open : [28.6      28.25     27.719999 28.389999 27.99     28.18     27.82
#  27.959999 27.68     27.549999 27.76     27.65     27.559999 27.49
#  27.129999 26.559999 26.299999 26.719999 26.26     25.860001 26.129999
#  26.35     26.700001 26.370001 26.709999 26.91     27.07     26.950001
#  27.09     27.1      27.290001 27.15     25.950001 26.469999 26.34
#  25.299999 25.549999 25.91     25.719999 25.59     25.01     23.450001
#  24.23     23.9      22.370001 22.25     20.26     20.700001 20.66
#  21.200001 21.52     20.51     22.07     22.969999 23.09     22.950001
#  23.059999 22.27     21.190001 20.559999 20.       21.09     22.549999
#  22.1      22.41     22.139999 22.309999 21.889999 21.16     22.530001
#  22.42     21.98     22.01     22.559999 22.76     23.549999 23.74
# ...

# %%
Auto
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2020-01-02  28.600000  28.650000  28.459999  28.639999  26.480253
# 1     2020-01-03  28.250000  28.379999  28.080000  28.129999  26.008713
# 2     2020-01-06  27.719999  28.059999  27.719999  28.049999  25.934746
# 3     2020-01-07  28.389999  28.389999  28.180000  28.209999  26.082678
# 4     2020-01-08  27.990000  28.219999  27.990000  28.129999  26.008713
# ...          ...        ...        ...        ...        ...        ...
# 1084  2024-04-24  34.700001  34.700001  34.330002  34.410000  34.410000
# 1085  2024-04-25  33.549999  33.730000  33.310001  33.650002  33.650002
# 1086  2024-04-26  33.639999  33.900002  33.630001  33.849998  33.849998
# 1087  2024-04-29  33.990002  34.110001  33.950001  34.099998  34.099998
# 1088  2024-04-30  34.279999  34.389999  33.990002  33.990002  33.990002
#
#        Volume
# 0      262800
# 1      663600
# 2      463000
# 3      341800
# 4      264200
# ...

# %%
sns.distplot(Auto["Volume"])
plt.show()

# %%
#Boxplot to check outliers

sns.boxplot(Auto["Volume"])
plt.show()

# %%
Q1=np.quantile(Auto["Volume"],0.25)
Q2=np.quantile(Auto["Volume"],0.5)
Q3=np.quantile(Auto["Volume"],0.75)

# %%
print("Q1:",Q1)
print("Q2:",Q2)
print("Q3:",Q3)
# Out:
# Q1: 674000.0
# Q2: 908600.0
# Q3: 1196400.0

# %%
IQR=Q3-Q1
print("IQR:",IQR)
# Out:
# IQR: 522400.0

# %%
UW=Q3+(1.5*IQR)
LW=Q1-(1.5*IQR)

print("Upper Whisker:",UW)
print("Lower Whisker:",LW)
# Out:
# Upper Whisker: 1980000.0
# Lower Whisker: -109600.0

# %%
sns.distplot(Auto["Open"])
plt.show()

# %%
#NUMERICAL DATA ANALYSIS=== CHECKING DATA DISTRIBUTION OF EACH THROUGH Skewness
Auto1=Auto.drop("Date",axis=1)

for column in Auto1:
    sns.distplot(Auto1[column])
    plt.show()
